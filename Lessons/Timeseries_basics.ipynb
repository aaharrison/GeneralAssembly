# %% [markdown]
# ## Exploring Rossmann Drug Store Sales Data

# %%
import os
import numpy
import pandas as pd

data = pd.read_csv('rossmann.csv', skipinitialspace=True,
                   low_memory=False)

# %% [markdown]
# Because we are most interested in the `Date` column that contains the date of sales for each store, we will make sure to process that as a `DateTime` type, and make that the index of our dataframe.

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data['Year'] = data.index.year
data['Month'] = data.index.month

# %%
store1_data = data[data.Store == 1]

# %%
store1_data.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-30      1          4   5020        546     1      1            0
# 2015-07-29      1          3   4782        523     1      1            0
# 2015-07-28      1          2   5011        560     1      1            0
# 2015-07-27      1          1   6102        612     1      1            0
#
#             SchoolHoliday  Year  Month
# Date
# 2015-07-31              1  2015      7
# 2015-07-30              1  2015      7
# 2015-07-29              1  2015      7
# 2015-07-28              1  2015      7
# 2015-07-27              1  2015      7

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# To compare sales on holidays, we can compare the sales using box-plots, which allows us to compare the distribution of sales on holidays against all other days. On state holidays the store is closed (and as a nice sanity check there are 0 sales), and on school holidays the sales are relatively similar.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12,8))

import seaborn as sns
# %matplotlib inline

sns.factorplot(
    x='SchoolHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
sns.factorplot(
    col='Open',
    x='DayOfWeek',
    y='Sales',
    data=store1_data,
    kind='box',
    
)

# %% [markdown]
# ### In class assignment:
#
# + Use the code above to explore if there are differences in sales on days with a promotion

# %%
data.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday  Year  Month
# Date
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7

# %%
sns.factorplot(
    col='Promo',
    x='DayOfWeek',
    y='Sales',
    data=store1_data,
    kind='box',
    
)

# %%
plt.figure(figsize = (20,12))
sns.boxplot(x = "DayOfWeek", y = "Sales", data = store1_data, hue = "Promo")

# %% [markdown]
# Lastly, we want to identify larger-scale trends in our data. How did sales change from 2014 to 2015? Were there any particularly interesting outliers in terms of sales or customer visits?

# %%
# Filter to days store 1 was open
store1_open_data = store1_data[store1_data.Open==1]
store1_open_data[['Sales']].plot()

# %%
store1_open_data[['Customers']].plot()

# %% [markdown]
# In pandas we can compute rolling average using the `pd.rolling_mean` or `pd.rolling_median` functions.

# %% [markdown]
# ### Data REFINING Using Time Series Statistics

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# To measure how much the sales are correlated with each other, we want to compute the _autocorrelation_ of the 'Sales' column. In pandas, we do this we with the `autocorr` function.
#
# `autocorr` takes one argument, the `lag` - which is how many prior data points should be used to compute the correlation. If we set the `lag` to 1, we compute the correlation between every point and the point directly preceding it, while setting `lag` to 10, computes the correlation between every point and the point 10 days earlier.

# %%
data['Sales'].resample('D').mean().autocorr(lag=1)
# Out:
# -0.025858276006383577

# %%
len(data['Sales'].resample('D').mean())
# Out:
# 942

# %%
for x in range(len(data['Sales'].resample('D').mean())):
    print(data['Sales'].resample('D').mean().autocorr(lag = x))
# Out:
# 1.0
# -0.0258582760064
# -0.0774434885663
# 0.0116002982781
# -0.0622513888638
# -0.192355899471
# -0.186080842166
# 0.557489358874
# -0.197226368708
# -0.235509613025
# -0.0697875468489
# -0.0297829447652
# -0.128213215205
# -0.05213738648
# 0.741900461325
# -0.0637154916433
# -0.10877746876
# -0.0203490583017
# -0.0441091236244
# -0.165048130518
# -0.1641123945
# 0.60399893015
# -0.172394373076
# -0.18748826894
# -0.0473279096198
# -0.028165913949
# -0.130673312493
# -0.102691139691
# 0.718112116053
# -0.0925389934415
# -0.129842458225
# -0.0490079878461
# -0.0613817344159
# -0.165542555159
# -0.151045828406
# 0.61350329181
# -0.155038045137
# -0.185034084461
# -0.0382800309511
# -0.0393031383853
# -0.152745461479
# -0.0828940930077
# 0.671139423008
# -0.107262875939
# -0.139407539607
# -0.0374802941093
# -0.0459146730049
# -0.158520576873
# -0.142395560727
# 0.652119048284
# -0.150916223784
# -0.187285767661
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-af3f6620b91f> in <module>()
#       1 for x in range(len(data['Sales'].resample('D').mean())):
# ----> 2     print(data['Sales'].resample('D').mean().autocorr(lag = x))
#
# //anaconda/lib/python3.5/site-packages/pandas/tseries/resample.py in f(self, _method, *args, **kwargs)
#     538     def f(self, _method=method, *args, **kwargs):
#     539         nv.validate_resampler_func(_method, args, kwargs)
# --> 540         return self._downsample(_method)
#     541     f.__doc__ = getattr(GroupBy, method).__doc__
#     542     setattr(Resampler, method, f)
#
# //anaconda/lib/python3.5/site-packages/pandas/tseries/resample.py in _downsample(self, how, **kwargs)
#     691         # we want to call the actual grouper method here
#     692         result = obj.groupby(
# --> 693             self.grouper, axis=self.axis).aggregate(how, **kwargs)
#     694
#     695         result = self._apply_loffset(result)
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    2658         _level = kwargs.pop('_level', None)
#    2659         if isinstance(func_or_funcs, compat.string_types):
# -> 2660             return getattr(self, func_or_funcs)(*args, **kwargs)
#    2661
#    2662         if hasattr(func_or_funcs, '__iter__'):
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in mean(self, *args, **kwargs)
#    1007         nv.validate_groupby_func('mean', args, kwargs)
#    1008         try:
# -> 1009             return self._cython_agg_general('mean')
#    1010         except GroupByError:
#    1011             raise
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_agg_general(self, how, numeric_only)
#     800
#     801             try:
# --> 802                 result, names = self.grouper.aggregate(obj.values, how)
#     803             except AssertionError as e:
#     804                 raise GroupByError(str(e))
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in aggregate(self, values, how, axis)
#    1894
#    1895     def aggregate(self, values, how, axis=0):
# -> 1896         return self._cython_operation('aggregate', values, how, axis)
#    1897
#    1898     def transform(self, values, how, axis=0):
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _cython_operation(self, kind, values, how, axis)
#    1851             counts = np.zeros(self.ngroups, dtype=np.int64)
#    1852             result = self._aggregate(
# -> 1853                 result, counts, values, labels, func, is_numeric)
#    1854         elif kind == 'transform':
#    1855             result = _maybe_fill(np.empty_like(values, dtype=out_dtype),
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _aggregate(self, result, counts, values, comp_ids, agg_func, is_numeric)
#    1911                 agg_func(result[:, :, i], counts, chunk, comp_ids)
#    1912         else:
# -> 1913             agg_func(result, counts, values, comp_ids)
#    1914
#    1915         return result
#
# KeyboardInterrupt:

# %%
data.groupby(pd.TimeGrouper(freq = "1B"))["Sales"].mean().autocorr(lag = 1)
# Out:
# 0.19800782635158617

# %%
plt.figure(figsize = (20,12))
data.groupby(pd.TimeGrouper(freq = "1D"))["Sales"].mean().plot()

# %% [markdown]
# ### Rolling Averages

# %% [markdown]
# If we want to investigate trends over time in sales, as always, we will start by computing simple aggregates.  We want to know what the mean and median sales were for each month and year.
#
# In Pandas, this is performed using the `resample` command, which is very similar to the `groupby` command. It allows us to group over different time intervals.
#
# We can use `data.resample` and provide as arguments:
#     - The level on which to roll-up to, 'D' for day, 'W' for week, 'M' for month, 'A' for year
#     - What aggregation to perform: 'mean', 'median', 'sum', etc.

# %%
data[['Sales']].resample('M').apply(['median', 'mean']).head()
# Out:
#              Sales
#             median         mean
# Date
# 2013-01-31  5194.0  5211.555578
# 2013-02-28  5421.5  5494.371397
# 2013-03-31  5844.0  5820.349168
# 2013-04-30  5464.0  5483.749836
# 2013-05-31  5585.0  5364.127383

# %% [markdown]
# While identifying the monthly averages are useful, we often want to compare the sales data of a date to a smaller window. To understand holidays sales, we don't want to compare late December with the entire month, but perhaps a few days surrounding it. We can do this using rolling averages.
#
# In pandas, we can compute rolling average using the `df.rolling().mean()` or `df.rolling().median()` functions.

# %%
data[['Sales']].resample('D').mean().rolling(window=3, center=True).mean().head()
# Out:
#                   Sales
# Date
# 2013-01-01          NaN
# 2013-01-02  4004.475720
# 2013-01-03  5960.120478
# 2013-01-04  5661.694170
# 2013-01-05  3807.010762

# %%
plt.figure(figsize = (20,12))
data.groupby(pd.TimeGrouper(freq = "D"))["Sales"].mean().rolling(window = 3, center=True).mean().plot()

# %% [markdown]
# `rolling()` takes these important parameters:
#     - `window` is the number of days to include in the average
#     - `center` is whether the window should be centered on the date or use data prior to that date
#     - `freq` is on what level to roll-up the averages to (as used in `resample`). Either `D` for day, `M` for month or `A` for year, etc.

# %% [markdown]
# Instead of plotting the full timeseries, we can plot the rolling mean instead, which smooths random changes in sales as well as removing outliers, helping us identify larger trends.

# %%
data[['Sales']].resample('D').mean().rolling(window=10, center=True).mean().plot()

# %% [markdown]
# ### Pandas Window functions
# Pandas `rolling_mean` and `rolling_median` are only two examples of Pandas window function capabilities. Window functions are operate on a set of N consecutive rows (a window) and produce an output.
#
# In addition to `rolling_mean` and `rolling_median`, there are `rolling_sum`, `rolling_min`, `rolling_max`... and many more.
#
# Another common one is `diff`, which takes the difference over time. `pd.diff` takes one arugment, `periods`, which is how many prio rows to use for the difference.

# %%
data['Sales'].diff(periods=1).head()
# Out:
# Date
# 2015-07-31       NaN
# 2015-07-31     801.0
# 2015-07-31    2250.0
# 2015-07-31    5681.0
# 2015-07-31   -9173.0
# Name: Sales, dtype: float64

# %% [markdown]
# ### Pandas expanding functions
#
# In addition to the set of `rolling_*` functions, Pandas also provides a similar collection of `expanding_*` functions, which, instead of using a window of N values, use all values up until that time.

# %%
# computes the average sales, from the first date _until_ the date specified.
data[['Sales']].resample('D').mean().expanding().mean().head()
# Out:
#                   Sales
# Date
# 2013-01-01    87.284560
# 2013-01-02  3160.157527
# 2013-01-03  4004.475720
# 2013-01-04  4491.911499
# 2013-01-05  4661.079513

# %% [markdown]
# ## Exercises

# %%
sb.factorplot(
    col='Open',
    hue='Promo',
    x='Month',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %% [markdown]
# ### In class assignment
#
# > Modify code above to Plot the distribution of sales by month and compare the effect of promotions

# %%
print(data[data["Open"] == 1].groupby(pd.TimeGrouper(freq = "1B"))["Sales"].mean().autocorr(lag = 1))
print("")
print(data[data["Open"] == 1].groupby(pd.TimeGrouper(freq = "1B"))["Sales"].mean().autocorr(lag = 30))
print("")
print(data[data["Open"] == 1].groupby(pd.TimeGrouper(freq = "1B"))["Sales"].mean().autocorr(lag = 365))
# Out:
# 0.516095493898
#
# 0.253195231759
#
# 0.398434827193

# %% [markdown]
# > Are sales more correlated with the prior date, a similar date last year, or a similar date last month?

# %%
average_daily_sales = data[['Sales', 'Open']].resample('D').mean()

print('Correlation with last day: {}'.format(average_daily_sales['Sales'].autocorr(lag=1)))
print('Correlation with last month: {}'.format(average_daily_sales['Sales'].autocorr(lag=30)))
print('Correlation with last year: {}'.format(average_daily_sales['Sales'].autocorr(lag=365)))
# Out:
# Correlation with last day: -0.0258582760064
# Correlation with last month: -0.129842458225
# Correlation with last year: 0.0202385294483

# %% [markdown]
# > Plot the 15 day rolling mean of customers in the stores

# %%
data[['Sales']].resample('D').mean().rolling(window=15).mean().plot()

# %% [markdown]
# > Identify the date with largest drop in sales from the same date in the previous month

# %%
average_daily_sales = data[['Sales', 'Open']].resample('D').mean()
average_daily_sales['DiffVsLastWeek'] = average_daily_sales[['Sales']].diff(periods=7)

average_daily_sales.sort_values(by='DiffVsLastWeek').head()

# Unsurprisingly, this day is Dec. 25 and Dec. 26 in 2014 and 2015. When the store is closed and there are many sales in the preceding week. How, about when the store is open?

average_daily_sales[average_daily_sales.Open == 1].sort_values(by='DiffVsLastWeek').head()

# The top values are Dec. 24 and then 2013-12-09 and 2013-10-14 where on average sales were 4k lower than the same day in the previous week.
# Out:
#                   Sales  Open  DiffVsLastWeek
# Date
# 2013-12-24  4693.101345   1.0    -7014.515695
# 2014-12-24  4933.386096   1.0    -5209.272727
# 2013-12-09  6822.938117   1.0    -4811.537220
# 2013-10-14  5893.636771   1.0    -4027.798206
# 2015-04-20  5909.294170   1.0    -4023.443049

# %% [markdown]
# > Compute the total sales up until Dec. 2014

# %%
total_daily_sales = data[['Sales']].resample('D').sum()

total_daily_sales.expanding().sum()['2014-12'].head()
# Out:
#                    Sales
# Date
# 2014-12-01  4.291837e+09
# 2014-12-02  4.300681e+09
# 2014-12-03  4.308939e+09
# 2014-12-04  4.317493e+09
# 2014-12-05  4.327295e+09

# %% [markdown]
# > When were the largest differences between 15-day moving/rolling averages?
# > HINT: Using `rolling(...).mean()` and `diff`

# %%
data[['Sales']].resample('d').mean().rolling(window=15).mean().diff(1).sort_values(by='Sales').head()

# Unsurprisingly, they occur at the beginning of every year after the holiday season.
# Out:
#                  Sales
# Date
# 2014-01-01 -773.446039
# 2015-01-01 -668.394774
# 2013-12-31 -663.000538
# 2014-01-05 -596.739073
# 2014-05-01 -585.158326
